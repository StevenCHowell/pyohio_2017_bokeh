# %% [markdown]
# # Imports
#
# When using the [`bokeh.plotting`](http://bokeh.pydata.org/en/latest/docs/user_guide/plotting.html) interface, here are a few of the most common ones we will use:
# * Use the [`figure`](http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.figure) function to  create new plot objects to work with.
# * Call the functions [`output_file`](http://bokeh.pydata.org/en/latest/docs/reference/resources_embedding.html#bokeh.io.output_file), [`output_notebook`](http://bokeh.pydata.org/en/latest/docs/reference/resources_embedding.html#bokeh.io.output_notebook), and [`output_server`](http://bokeh.pydata.org/en/latest/docs/reference/resources_embedding.html#bokeh.io.output_server) (possibly in combination) to tell Bokeh how to display or save output.
# * Execute [`show`](http://bokeh.pydata.org/en/latest/docs/reference/resources_embedding.html#bokeh.io.show) and  [`save`](http://bokeh.pydata.org/en/latest/docs/reference/resources_embedding.html#bokeh.io.save) to display or save plots and layouts.

# %%
import bokeh.plotting

# %% [markdown]
# Load the bokeh JavaScript layer from the web.

# %%
bokeh.plotting.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a34df05f-f4ca-4360-b096-cda46144c27a">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# If not connected to the internet, you can get the JavaScript library inline by running
#
# ```
# import bokeh.resources
# bokeh.plotting.output_notebook(resources=bokeh.resources.INLINE)
# ```

# %%
# # uncomment and run this cell if not connected to the internet
# import bokeh.resources
# bokeh.plotting.output_notebook(resources=bokeh.resources.INLINE)

# %% [markdown]
# Bokeh incorporates many [palettes](http://bokeh.pydata.org/en/latest/docs/reference/palettes.html#bokeh-palettes) for presenting your data.  The following import method makes it easy to switch out which palette you are using.

# %%
from bokeh.palettes import Category10_10 as palette
# # switching palettes is as easy as replacing which you import
# from bokeh.palettes import Colorblind_7 as palette

# %% [markdown]
# Palettes are simply a list of color hex strings.

# %%
print(palette)
# Out:
# ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# %% [markdown]
# You can also use many color names, e.g., `'blue'`, `'red'`, `'yellow'`, `'firebrick'`, etc.  Feel free to explore.

# %% [markdown]
# Bokeh expects data as either a single value, or a series of values, e.g., list, set, NumPy array, Pandas DataFrame column.  We will mostly use NumPy arrays.

# %%
import numpy as np

# %% [markdown]
# We will use SciPy to create some sample data.

# %%
import scipy.stats

# %% [markdown]
# # Sample plot

# %% [markdown]
# First we will put together some sample data.

# %%
x = np.linspace(-2*np.pi, 2*np.pi)
y_sin = np.sin(x)
y_cos = np.cos(x)
y_tan = np.tan(x)

# %%
p = bokeh.plotting.figure()
p.diamond(x, y_sin)
bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d77ca850-85bf-4165-aeab-93a26b019014"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d77ca850-85bf-4165-aeab-93a26b019014");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d77ca850-85bf-4165-aeab-93a26b019014");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd77ca850-85bf-4165-aeab-93a26b019014' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"03cb78a8-2814-4ef8-93b1-eafa38283186":{"roots":{"references":[{"attributes":{"data_source":{"id":"8d461994-05cf-463c-a77e-310145dc3466","type":"ColumnDataSource"},"glyph":{"id":"db2cbf7a-b42b-493e-b404-11b06491d43b","type":"Diamond"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"e1118cbe-f286-4e18-917f-01d0438a4632","type":"Diamond"},"selection_glyph":null},"id":"48fcc199-3920-420e-9fe5-524ed76e9993","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"2b33c51e-76c7-4948-8255-8af4531c1c64","type":"BasicTickFormatter"},"plot":{"id":"42806861-b665-4e4c-a49f-1da87689e939","subtype":"Figure","type":"Plot"},"ticker":{"id":"d8c2d040-9339-4c22-9433-a6fef5d1e50f","type":"BasicTicker"}},"id":"22b3222e-f5a7-4ffd-929f-6ff76471a286","type":"LinearAxis"},{"attributes":{},"id":"d8c2d040-9339-4c22-9433-a6fef5d1e50f","type":"BasicTicker"},{"attributes":{},"id":"2b33c51e-76c7-4948-8255-8af4531c1c64","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"42806861-b665-4e4c-a49f-1da87689e939","subtype":"Figure","type":"Plot"},"ticker":{"id":"d8c2d040-9339-4c22-9433-a6fef5d1e50f","type":"BasicTicker"}},"id":"2a427c7d-2d12-4d0e-b953-5c708a51237f","type":"Grid"},{"attributes":{"formatter":{"id":"7031a1b4-cea0-4994-97b2-38fee2dabe20","type":"BasicTickFormatter"},"plot":{"id":"42806861-b665-4e4c-a49f-1da87689e939","subtype":"Figure","type":"Plot"},"ticker":{"id":"78810260-83df-40a1-9c73-01e814c04b02","type":"BasicTicker"}},"id":"ba803769-f535-4e33-b04b-40c7c0f4175e","type":"LinearAxis"},{"attributes":{},"id":"78810260-83df-40a1-9c73-01e814c04b02","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e1118cbe-f286-4e18-917f-01d0438a4632","type":"Diamond"},{"attributes":{"plot":null,"text":""},"id":"0d9a9dcc-35c1-4e62-abc8-00b2db655b92","type":"Title"},{"attributes":{"dimension":1,"plot":{"id":"42806861-b665-4e4c-a49f-1da87689e939","subtype":"Figure","type":"Plot"},"ticker":{"id":"78810260-83df-40a1-9c73-01e814c04b02","type":"BasicTicker"}},"id":"a320e5dc-56eb-48bd-aa26-22d6442a21b8","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"d885c553-bc37-4d0b-9542-e438e6f40f7e","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"db2cbf7a-b42b-493e-b404-11b06491d43b","type":"Diamond"},{"attributes":{"plot":{"id":"42806861-b665-4e4c-a49f-1da87689e939","subtype":"Figure","type":"Plot"}},"id":"545073b1-84d5-4787-b9f3-61c9a3b25a1a","type":"PanTool"},{"attributes":{"plot":{"id":"42806861-b665-4e4c-a49f-1da87689e939","subtype":"Figure","type":"Plot"}},"id":"b92b1483-33b3-4e73-aec9-dd880ac4379b","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"d885c553-bc37-4d0b-9542-e438e6f40f7e","type":"BoxAnnotation"},"plot":{"id":"42806861-b665-4e4c-a49f-1da87689e939","subtype":"Figure","type":"Plot"}},"id":"54ef3d64-2682-4021-842e-baddee26b208","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"42806861-b665-4e4c-a49f-1da87689e939","subtype":"Figure","type":"Plot"}},"id":"ea626e59-3906-4322-9c46-1a396b0347ee","type":"SaveTool"},{"attributes":{"plot":{"id":"42806861-b665-4e4c-a49f-1da87689e939","subtype":"Figure","type":"Plot"}},"id":"1d378de9-c3b7-4be8-a7c3-6df2c0cee692","type":"ResetTool"},{"attributes":{"plot":{"id":"42806861-b665-4e4c-a49f-1da87689e939","subtype":"Figure","type":"Plot"}},"id":"63e0a3bf-6a3c-4c91-ae5f-3577cf55532d","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[50]},"y":{"__ndarray__":"... ...

# %% [markdown]
# Many of these functions have `kwargs` you can use to adjust the results.  Lets see some of these in use.

# %%
p = bokeh.plotting.figure(title='Demo Plot',
                          x_axis_label='x',
                          y_axis_label='f(x)',
                          width=400, height=350,
                          x_range=(-7, 7),
                          y_range=(-1.5, 2))

p.diamond(x, y_sin, 
          line_color=palette[0], 
          fill_color=palette[1],
          line_alpha=((y_sin+1)/2), # oscillate from 0 to 1 (y min to max)
          fill_alpha=((1-y_sin)/2), # oscillate from 1 to 0 (y min to max)
          legend='Sine', size=10)

bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="13d77557-a848-4806-af7b-d16120b26b26"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("13d77557-a848-4806-af7b-d16120b26b26");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("13d77557-a848-4806-af7b-d16120b26b26");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '13d77557-a848-4806-af7b-d16120b26b26' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"cd5e7e72-4f71-4af2-aa85-a95e54c53c20":{"roots":{"references":[{"attributes":{},"id":"f54cf2af-47a6-404c-991e-68406aca2531","type":"BasicTickFormatter"},{"attributes":{"callback":null,"end":7,"start":-7},"id":"fb26dfec-2f50-483a-af08-f9742f41e784","type":"Range1d"},{"attributes":{"overlay":{"id":"92fb5273-a53a-4bfb-b876-232283e45302","type":"BoxAnnotation"},"plot":{"id":"ba9cd0d7-924e-4431-bf88-6904b0428fb3","subtype":"Figure","type":"Plot"}},"id":"8cd3270a-ef5a-48d6-8de9-b82967cf789e","type":"BoxZoomTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"value":"#ff7f0e"},"line_alpha":{"field":"line_alpha"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"a508decb-239e-4cdb-a48b-9a8b65edb2eb","type":"Diamond"},{"attributes":{"axis_label":"f(x)","formatter":{"id":"1a6b0689-fdcb-4ab1-aa54-1b6f1ecaaf5c","type":"BasicTickFormatter"},"plot":{"id":"ba9cd0d7-924e-4431-bf88-6904b0428fb3","subtype":"Figure","type":"Plot"},"ticker":{"id":"571a23b4-5cfd-4467-af00-9bd0dee00434","type":"BasicTicker"}},"id":"4724071c-278d-4cd6-ab6b-6b568e0d0562","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"d8792d44-3637-45b8-aa4b-59c910a81389","type":"Diamond"},{"attributes":{"label":{"value":"Sine"},"renderers":[{"id":"43f39048-4d24-4f7c-a071-6ddfa62d5069","type":"GlyphRenderer"}]},"id":"8ac1f85a-17a8-4d6c-85ff-db632e059696","type":"LegendItem"},{"attributes":{"below":[{"id":"dc6424c5-13ef-4f38-84de-ad3eac67fb06","type":"LinearAxis"}],"left":[{"id":"4724071c-278d-4cd6-ab6b-6b568e0d0562","type":"LinearAxis"}],"plot_height":350,"plot_width":400,"renderers":[{"id":"dc6424c5-13ef-4f38-84de-ad3eac67fb06","type":"LinearAxis"},{"id":"d21dcdce-4976-42bc-8e32-93871e12dc86","type":"Grid"},{"id":"4724071c-278d-4cd6-ab6b-6b568e0d0562","type":"LinearAxis"},{"id":"a1286568-c209-48fa-b4dd-061d70674bef","type":"Grid"},{"id":"92fb5273-a53a-4bfb-b876-232283e45302","type":"BoxAnnotation"},{"id":"b8066323-a7ce-4ad1-bba1-b2bf55bf7429","type":"Legend"},{"id":"43f39048-4d24-4f7c-a071-6ddfa62d5069","type":"GlyphRenderer"}],"title":{"id":"fd1fac70-0217-45c4-bad5-c33b0b09dee9","type":"Title"},"tool_events":{"id":"2c4a8d55-55f9-4390-86c1-6170af71ad30","type":"ToolEvents"},"toolbar":{"id":"00d47552-f751-4387-b99b-0ecd499052ab","type":"Toolbar"},"x_range":{"id":"fb26dfec-2f50-483a-af08-f9742f41e784","type":"Range1d"},"x_scale":{"id":"907ec8b8-96f3-4787-b2a6-1e92c1445358","type":"LinearScale"},"y_range":{"id":"703fafda-1c46-49fc-9aa1-e82eef569fbd","type":"Range1d"},"y_scale":{"id":"62e11b8c-9bc3-4319-b18a-213a006cb1ed","type":"LinearScale"}},"id":"ba9cd0d7-924e-4431-bf88-6904b0428fb3","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"ba9cd0d7-924e-4431-bf88-6904b0428fb3","subtype":"Figure","type":"Plot"}},"id":"7341823f-04a6-4eef-b4d8-6bdee78fc0fd","type":"PanTool"},{"attributes":{"callback":null,"column_names":["x","y","fill_alpha","line_alpha"],"data":{"fill_alpha":{"__ndarray__":"...","dtype":"float64","shape":[50]},"line_alpha":{"__ndarray__":"...","dtype":"float64","shape":[50]},"x":{"__ndarray__":"...","dtype":"float64","shape":[50]},"y":{"__ndarray__":"...","dtype":"float64","shape":[50]}}},"id":"6bd25865-63c1-47e5-a258-acc0300bd430","type":"ColumnDataSource"},{"attributes":{"callback":null,"end":2,"start":-1.5},"id":"703fafda-1c46-49fc-9aa1-e82eef569fbd","type":"Range1d"},{"attributes":{"axis_label":"x","formatter":{"id":"f54cf2af-47a6-404c-991e-68406aca2531","type":"BasicTickFormatter"},"plot":{"id":"ba9cd0d7-924e-4431-bf88-6904b0428fb3","subtype":"Figure","type":"Plot"},"ticker":{"id":"49725542-86d7-4a9f-8399-e2311004ae2e","type":"BasicTicker"}},"id":"dc6424c5-13ef-4f38-84de-ad3eac67fb06","type":"LinearAxis"},{"attributes":{"plot":{"id":"ba9cd0d7-924e-4431-bf88-6904b ...

# %% [markdown]
# Note that you can use `color` to set both the `line_color` and `fill_color`.  Similarly, `alpha` sets both the `line_alpha` and `fill_alpha`.

# %%
p = bokeh.plotting.figure(title='Demo Plot',
                          x_axis_label='x',
                          y_axis_label='f(x)',
                          width=400, height=350,
                          x_range=(-7, 7),
                          y_range=(-1.5, 2))

p.diamond(x, y_sin, 
          color=palette[0], 
          alpha=((y_sin+1)/2), # oscillate from 0 to 1 (y min to max)
          legend='Sine', size=10)

bokeh.plotting.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="06d951f6-f3c0-487b-8bcf-7a773c8fbe8e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("06d951f6-f3c0-487b-8bcf-7a773c8fbe8e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("06d951f6-f3c0-487b-8bcf-7a773c8fbe8e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '06d951f6-f3c0-487b-8bcf-7a773c8fbe8e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a3616ff6-d040-4dcd-ab02-10276f7bf328":{"roots":{"references":[{"attributes":{"plot":null,"text":"Demo Plot"},"id":"e8aa0c75-37ee-42c4-b65e-365162ec575d","type":"Title"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b1c3b5e6-c2a6-4576-8c01-b1127e087fd8","type":"BoxAnnotation"},{"attributes":{},"id":"14d5c20a-9992-4f66-8492-b73b8610a296","type":"ToolEvents"},{"attributes":{"callback":null,"end":2,"start":-1.5},"id":"460abd24-fc00-427a-a374-bb406372b396","type":"Range1d"},{"attributes":{"plot":{"id":"7443b20f-dd62-4bca-8d9e-26d2defd65be","subtype":"Figure","type":"Plot"}},"id":"162e6262-53b1-410f-81b4-892e1b726edb","type":"SaveTool"},{"attributes":{"plot":{"id":"7443b20f-dd62-4bca-8d9e-26d2defd65be","subtype":"Figure","type":"Plot"}},"id":"8781709f-9c29-44e8-add1-ca6f5228f138","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"b1c3b5e6-c2a6-4576-8c01-b1127e087fd8","type":"BoxAnnotation"},"plot":{"id":"7443b20f-dd62-4bca-8d9e-26d2defd65be","subtype":"Figure","type":"Plot"}},"id":"d6e2fd87-1e63-486b-a017-483cbdad2736","type":"BoxZoomTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"value":"#1f77b4"},"line_alpha":{"field":"line_alpha"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"51aa69c3-0bfb-4467-a92e-7ac1ba8c9280","type":"Diamond"},{"attributes":{},"id":"382f06dd-5c46-435e-9e9d-3c5acbcad09f","type":"LinearScale"},{"attributes":{"callback":null,"column_names":["x","y","fill_alpha","line_alpha"],"data":{"fill_alpha":{"__ndarray__":"...","dtype":"float64","shape":[50]},"line_alpha":{"__ndarray__":"...","dtype":"float64","shape":[50]},"x":{"__ndarray__":"...","dtype":"float64","shape":[50]},"y":{"__ndarray__":"...","dtype":"float64","shape":[50]}}},"id":"b8b7b6ba-3254-4f5d-ab73-8065d6d4e85a","type":"ColumnDataSource"},{"attributes":{"axis_label":"x","formatter":{"id":"b1333235-45a6-47c5-aebf-9c1d4e45f215","type":"BasicTickFormatter"},"plot":{"id":"7443b20f-dd62-4bca-8d9e-26d2defd65be","subtype":"Figure","type":"Plot"},"ticker":{"id":"33324bbe-1f35-4818-9b0b-3f8c1328dd0d","type":"BasicTicker"}},"id":"f2926419-8cc5-4fd0-8616-a8d00053dbb1","type":"LinearAxis"},{"attributes":{},"id":"6e117b3f-7af7-4ad2-bda9-02a8b742f7d2","type":"BasicTicker"},{"attributes":{"plot":{"id":"7443b20f-dd62-4bca-8d9e-26d2defd65be","subtype":"Figure","type":"Plot"},"ticker":{"id":"33324bbe-1f35-4818-9b0b-3f8c1328dd0d","type":"BasicTicker"}},"id":"613a8e8c-11ab-4756-a62a-b0cc7dedc5ca","type":"Grid"},{"attributes":{},"id":"7728c8a7-1e04-4270-afce-0c5cd28c195f","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"7443b20f-dd62-4bca-8d9e-26d2defd65be","subtype":"Figure","type":"Plot"},"ticker":{"id":"6e117b3f-7af7-4ad2-bda9-02a8b742f7d2","type":"BasicTicker"}},"id":"e9127ec8-60dc-4d02-bf1b-438cc578bb7d","type":"Grid"},{"attributes":{},"id":"b1333235-45a6-47c5-aebf-9c1d4e45f215","type":"BasicTickFormatter"},{"attributes":{},"id":"33324bbe-1f35-4818-9b0b-3f8c1328dd0d","type":"BasicTicker"},{"attributes":{"data_source":{"id":"b8b7b6ba-3254-4f5d-ab73-8065d6d4e85a","type":"ColumnDataSource"},"glyph":{"id":"51aa69c3-0bfb-4467-a92e-7ac1ba8c9280","type":"Diamond"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"59ee4c12-288a-4c74-8694-620d6729d8ba","type":"Diamond"},"selection_glyph":null},"id":"3d4f90ce-675c-4aaf-81f5-5761c89f9b28","type":"GlyphRenderer"},{"attributes":{"callback":null,"end":7,"start":-7},"id":"204a454b-3a24-4e83-81b4-060661baa5ad","type":"Range1d"},{"attributes":{"plot":{"id":"7443b20f-dd62-4bca-8d9e-26d2defd65be","subtype":"Figure","type":"Plot"}},"id":"41f5cebe-a541-469c-9ab7-6ba956e5d121","type":"PanTool"},{"attribute ...

# %% [markdown]
# # Exercise
# Plot all three data sets together.  For each data set, use a different value for each of the following:
# - `glyph`
# - `color` (or `line_color` and `fill_color` separately)
# - `alpha` (or `line_alpha` and `fill_alpha` separately)
# - `legand`

# %%
from bokeh.palettes import

# %% [markdown]
# $$f(x | \mu, \sigma^2) = \frac{1}{\sqrt{2\pi\sigma^2}} \,\exp\left({-\frac{(x-\mu)^2}{2\sigma^2}}\right)$$

# %%
def gaussian(x_array, mu, sigma):
    pdf = scipy.stats.norm.pdf(x_array, loc=mu, scale=sigma)
    return pdf
