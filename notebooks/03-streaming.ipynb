# %%
import time
import numpy as np

# %%
from bokeh.models.sources import ColumnDataSource
from bokeh.plotting import figure
from bokeh.io import output_notebook, show, push_notebook

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4344939e-8b49-4b10-a354-bb7724c03e1c">Loading BokehJS ...</span>
#     </div>

# %%
my_figure = figure(plot_width=800, plot_height=400)
test_data = ColumnDataSource(data=dict(x=[0], y=[0]))
line = my_figure.line("x", "y", source=test_data)
handle = show(my_figure, notebook_handle=True)

new_data=dict(x=[0], y=[0])
x = []
y = []

step = 0
step_size = 0.1  # increment for increasing step
max_step = 10  # arbitrary stop point for example
period = .1  # in seconds (simulate waiting for new data)
n_show = 10  # number of points to keep and show
while step < max_step:
    x.append(step)
    y.append(np.random.rand())
    
    new_data['x'] = x = x[-n_show:]  # prevent filling ram 
    new_data['y'] = y = y[-n_show:]  # prevent filling ram

    test_data.stream(new_data, n_show)

    push_notebook(handle=handle)
    step += step_size
    time.sleep(period)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="01034906-e80b-4641-9fe8-a01f7241c649"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("01034906-e80b-4641-9fe8-a01f7241c649");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("456b0a8d-97d8-4f44-8a81-cf3db510cbc4", function () {});
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("01034906-e80b-4641-9fe8-a01f7241c649");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '01034906-e80b-4641-9fe8-a01f7241c649' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0300fe5f-48de-4ccf-a631-09016f4417b0":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b1e630b5-021c-451c-abee-90e929c652d5","type":"PanTool"},{"id":"75a69259-e9b4-40cc-9f45-2b99434d2658","type":"WheelZoomTool"},{"id":"abf73875-ffe2-4431-b707-75da378cd77d","type":"BoxZoomTool"},{"id":"d453ce6a-4333-4e8e-9f2d-cb33cd04a5ea","type":"SaveTool"},{"id":"bce3345f-92ff-4b1d-90c0-8ba6adba9c7c","type":"ResetTool"},{"id":"81a3e3ae-4d80-4734-a2b4-bc2f560c301a","type":"HelpTool"}]},"id":"ccf577b1-52d9-4b50-adf0-9773827849bb","type":"Toolbar"},{"attributes":{},"id":"781d0ea9-b5e4-44bd-ac31-587becbd53d1","type":"BasicTicker"},{"attributes":{"formatter":{"id":"a5f8378d-e0f5-4ddd-8adb-1c019de9f9ab","type":"BasicTickFormatter"},"plot":{"id":"81a409b3-7162-4776-a55e-134762ceb9de","subtype":"Figure","type":"Plot"},"ticker":{"id":"48c106d0-f675-45e1-bda3-aef66efc6b22","type":"BasicTicker"}},"id":"039303d4-fb6a-45da-ac70-74401bf48989","type":"LinearAxis"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"53ba0828-95e9-4353-91b9-71a9440b9325","type":"Line"},{"attributes":{},"id":"48c106d0-f675-45e1-bda3-aef66efc6b22","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"81a409b3-7162-4776-a55e-134762ceb9de","subtype":"Figure","type":"Plot"},"ticker":{"id":"48c106d0-f675-45e1-bda3-aef66efc6b22","type":"BasicTicker"}},"id":"b225f489-8b8e-4109-95bc-a030080d56de","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"516e62eb-adc3-47d9-b33e-e3b505d72546","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"81a409b3-7162-4776-a55e-134762ceb9de","subtype":"Figure","type":"Plot"}},"id":"75a69259-e9b4-40cc-9f45-2b99434d2658","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"81a409b3-7162-4776-a55e-134762ceb9de","subtype":"Figure","type":"Plot"}},"id":"b1e630b5-021c-451c-abee-90e929c652d5","type":"PanTool"},{"attributes":{"data_source":{"id":"97a5afce-f409-4cd8-93e0-c67aa89954cf","type":"ColumnDataSource"},"glyph":{"id":"53ba0828-95e9-4353-91b9-71a9440b9325","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"6d005ed5-ac8d-4213-b86a-6d24b4e5989d","type":"Line"},"selection_glyph":null},"id":"13eb6711-d5a0-49cb-8497-e3cdbcd01303","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"516e62eb-adc3-47d9-b33e-e3b505d72546","type":"BoxAnnotation"},"plot":{"id":"81a409b3-7162-4776-a55e-134762ceb9de","subtype":"Figure","type":"Plot"}},"id":"abf73875-ffe2-4431-b707-75da378cd77d","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"81a409b3-7162-4776-a55e-134762ceb9de","subtype":"Figure","type":"Plot"}},"id":"bce3345f-92ff-4b1d-90c0-8ba6adba9c7c","type":"ResetTool"},{"attributes":{"plot":{"id":"81a409b3-7162-4776-a55e-134762ceb9de","subtype":"Figure","type":"Plot"}},"id":"d453ce6a-4333-4e8e-9f2d-cb33cd04a5ea","type":"SaveTool"},{"attributes":{"plot":{"id":"81a409b3-7162-4776-a55e-134762ceb9de","subtype":"Figure","type":"Plot"}},"id":"81a3e3ae-4d80-4734-a2b4-bc2f560c301a","type":"HelpTool"},{"attributes":{},"id":"a5f8378d-e0f5-4ddd-8adb-1c019de9f9ab","type":"BasicTickFormatter"},{"attributes":{},"id":"16291cd9-dccf-4b18-9e55-aa188b7fc9c6","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"6d77493f-c72a-4998-9a6e-8dfef65169a9","type":"LinearAxis"}],"left":[{"id":"039303d4-fb6a-45da-ac70-74401bf48989","type":"LinearAxis"}],"plot_height":400,"plot_width":800,"renderers":[{"id":"6d77493f-c72a-4998-9a6e-8dfef65169a9","type":"LinearAxis"},{"id":"5beb6c16-94ba-4bae-889d-e94ff869f6c6","type":"Grid"},{"id":"039303d4-fb6a-45da-ac70-74401bf48989","type":"LinearAxis"},{"id":"b225f489-8b8e ...
